# %%
import openai
import re
import httpx
import os
from dotenv import load_dotenv
#
_ = load_dotenv()
from openai import OpenAI

# %%
pip install httpx

# %%
client = OpenAI(api_key="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")

# %%
try:
    chat_completion = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[{"role": "user", "content": "Hello world"}]
    )
    print(chat_completion.choices[0].message.content)
except Exception as e:
    print(f"Erro ao chamar a API: {e}")
    print("Dica: Este erro 'insufficient_quota' significa que você precisa adicionar créditos em sua conta no site da OpenAI.")
# Out:
# Hello! How can I assist you today?

# %%
chat_completion.choices[0].message.content
# Out:
# 'Hello! How can I assist you today?'

# %%
class Agent:
    def __init__(self, system=""):
        self.system = system
        self.messages = []
        if self.system:
            self.messages.append({"role": "system", "content": system})

    def __call__(self, message):
        self.messages.append({"role": "user", "content": message})
        result = self.execute()
        self.messages.append({"role": "assistant", "content": result})
        return result

    def execute(self):
        completion = client.chat.completions.create(
                        model="gpt-4o",
                        temperature=0,
                        messages=self.messages)
        return completion.choices[0].message.content

# %%
prompt = """
Você vai agir em looping com 3 ações: Pensamento, Distancia, Rotas, Sugestão.
Seu objetivo é planejar comigo uma viagem entre varias cidades e traçar a melhor rota com menos tempo.

Suas ações disponiveis são:

Pensamento:
Você irá me retornar os seus pensamentos para eu entender sua logica.

Distancia:
Irá listar a distancia de uma cidade para outra no modelo de: A para B[2 horas].
Depois de listar, irá me retornar apenas os resultados.

Rotas:
Você mostrará as rotas mais economicas entre as viagens.

Sugestão:
Com o calculo de rotas e distancias você irá dar a melhor sugestão das rotas.

Exemplo de conversa:
Pergunta: Me Dê um roteiro de viagem da cidade A, B e C. Tudo usando o carro.
Pensamento: Irei calcular a distancia entre cidade A para B, A e C, B e C, B e A, C e A, C e B.
Distancia: A para B[3 horas], A para C[2 Horas], B para C[1 Hora], B para A[4 Hora], C para A[1 Hora], C para B[2 Hora].
Pensamento: Devo calcular todas as rotas possiveis passando pelas cidades, sendo elas:
A para B para C, A para C para B, B para A para C, B para C para A, C para A para B, C para B para A.
Rotas: A>B>C[4 Horas], A>C>B[3 Horas](não irei escrever o resto, você entendeu).
Pensamento: A>B>C é a melhor rota.
Sugestão: A>B>C.

Esse é apenas um exemplo, haverá outras vezes que apenas pedirei a ação de distancia, outras a ação de rotas...


""".strip()

print(chat_completion.choices[0].message.content)
# Out:
# Hello! How can I assist you today?

# %%
abot = Agent(prompt)

# %%
result = abot("Faça um roteiro entre recife, Olinda e Jaboatão?")
print(result)
# Out:
# Pensamento: Irei calcular a distância entre Recife para Olinda, Recife para Jaboatão, Olinda para Jaboatão, Olinda para Recife, Jaboatão para Recife, Jaboatão para Olinda.
#
# Distancia: Recife para Olinda [30 minutos], Recife para Jaboatão [40 minutos], Olinda para Jaboatão [50 minutos], Olinda para Recife [30 minutos], Jaboatão para Recife [40 minutos], Jaboatão para Olinda [50 minutos].
#
# Pensamento: Devo calcular todas as rotas possíveis passando pelas cidades, sendo elas:
# Recife para Olinda para Jaboatão, Recife para Jaboatão para Olinda, Olinda para Recife para Jaboatão, Olinda para Jaboatão para Recife, Jaboatão para Recife para Olinda, Jaboatão para Olinda para Recife.
#
# Rotas: Recife>Olinda>Jaboatão [1 hora e 20 minutos], Recife>Jaboatão>Olinda [1 hora e 30 minutos], Olinda>Recife>Jaboatão [1 hora e 10 minutos], Olinda>Jaboatão>Recife [1 hora e 30 minutos], Jaboatão>Recife>Olinda [1 hora e 10 minutos], Jaboatão>Olinda>Recife [1 hora e 20 minutos].
#
# ...

# %%
result = abot("Agora adicione nessa viagem a ida para São Lourenço")
print(result)
# Out:
# Pensamento: Irei calcular a distância adicional entre Recife para São Lourenço, Olinda para São Lourenço, Jaboatão para São Lourenço, São Lourenço para Recife, São Lourenço para Olinda, São Lourenço para Jaboatão.
#
# Distancia: Recife para São Lourenço [50 minutos], Olinda para São Lourenço [1 hora], Jaboatão para São Lourenço [30 minutos], São Lourenço para Recife [50 minutos], São Lourenço para Olinda [1 hora], São Lourenço para Jaboatão [30 minutos].
#
# Pensamento: Devo calcular todas as rotas possíveis passando pelas cidades, sendo elas:
# ...
